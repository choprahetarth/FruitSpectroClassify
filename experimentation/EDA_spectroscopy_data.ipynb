# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
#started the exploratory data analysis

# %%
df = pd.read_csv('spectro1.csv',sep =",")
df.head(444)
# Out:
#            A       B      C        D       E        F       G       H       I  \
# 0    1668.42  463.18  878.53  317.17  823.73  1628.71  286.43  295.68  133.87
# 1    1103.17  301.52  538.97  180.19  337.68   631.86   53.34   73.51   48.59
# 2    1489.77  443.20  873.83  325.45  816.00  1592.00  324.12  332.43  148.16
# 3     892.30  286.08  560.60  239.95  694.68  1554.58  231.35  258.93  125.29
# 4    1122.70  333.31  704.52  223.40  697.00  1485.39  126.40  168.96  104.81
# ..       ...     ...     ...     ...     ...      ...     ...     ...     ...
# 439   329.00  100.81  220.10   70.79  140.64   144.02   31.89   44.43   51.45
# 440   434.43  118.07  203.17   63.43  126.73   288.04   46.39   72.41   81.94
# 441   907.92  219.78  447.73  103.89  255.77   589.50   23.77   35.66   38.11
# 442   555.49  151.67  336.74   69.87  187.77   377.00   24.93   37.85   46.21
# 443   419.79  130.78  221.04   79.98  139.86   259.10   94.51  128.37   83.85
#
# ...

# %%
df.shape
# Out:
# (444, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 444 entries, 0 to 443
# Data columns (total 19 columns):
# A        444 non-null float64
# B        444 non-null float64
# C        444 non-null float64
# D        444 non-null float64
# E        444 non-null float64
# F        444 non-null float64
# G        444 non-null float64
# H        444 non-null float64
# I        444 non-null float64
# J        444 non-null float64
# K        444 non-null float64
# L        444 non-null float64
# M        444 non-null float64
# N        444 non-null float64
# O        444 non-null float64
# P        444 non-null float64
# Q        444 non-null float64
# R        444 non-null float64
# Label    444 non-null int64
# dtypes: float64(18), int64(1)
# memory usage: 66.0 KB

# %%
df.describe()
# Out:
#                  A           B           C            D            E  \
# count   444.000000  444.000000   444.000000  444.000000   444.000000
# mean    637.469122  198.018626   391.381261  129.792590   293.039887
# std     448.133254  112.888519   256.246495   83.608325   242.818999
# min      31.240000   16.350000    28.220000   18.390000    35.550000
# 25%     333.635000  118.970000   214.225000   73.550000   143.730000
# 50%     516.440000  171.650000   320.280000  103.890000   212.885000
# 75%     821.032500  248.850000   475.715000  156.290000   337.875000
# max    2749.140000  929.090000  1978.100000  763.970000  2065.500000
#
#                  F           G           H           I           J  \
# count   444.000000  444.000000  444.000000  444.000000  444.000000
# mean    504.039775   74.359279  107.933874  107.622928   83.844459
# std     466.386074   73.620765   90.002088   51.845310   28.287793
# min      23.300000   15.660000   19.750000   20.480000   16.550000
# ...

# %%
df.Label.value_counts()
# Out:
# 3    283
# 2    158
# 1      3
# Name: Label, dtype: int64

# %%
plt.figure(figsize=(6,4))
sns.heatmap(df.corr(),cmap='Blues',annot=False)

# %%
k = 18 #number of variables for heatmap
cols = df.corr().nlargest(k, 'Label')['Label'].index
cm = df[cols].corr()
plt.figure(figsize=(11,8))
sns.heatmap(cm, annot=True, cmap = 'viridis')

# %%
l = df.columns.values
number_of_columns=18
number_of_rows = len(l)-1/number_of_columns
plt.figure(figsize=(number_of_columns,5*number_of_rows))
for i in range(0,len(l)):
    plt.subplot(number_of_rows + 1,number_of_columns,i+1)
    sns.set_style('whitegrid')
    sns.boxplot(df[l[i]],color='green',orient='v')
    plt.tight_layout()

# %%
plt.figure(figsize=(2*number_of_columns,5*number_of_rows))
for i in range(0,len(l)):
    plt.subplot(number_of_rows + 1,number_of_columns,i+1)
    sns.distplot(df[l[i]],kde=True)

# %%
df.loc[:,"K"].var()
# Out:
# 27025.463886112295

# %%
df.loc[:,"L"].var()
# Out:
# 1697.9717608743617

# %%
df.loc[:,"Q"].var()
# Out:
# 62249.82995143016

# %%
df.loc[:,"R"].var()
# Out:
# 399203.47368493845

# %%
new_df=df.groupby(np.arange(len(df))//3).mean()

# %%
new_df.describe()
# Out:
#                  A           B           C            D           E  \
# count   148.000000  148.000000   148.000000  148.000000  148.000000
# mean    637.469122  198.018626   391.381261  129.792590  293.039887
# std     324.187582   81.587157   179.616180   58.144531  167.246836
# min     159.453333   59.336667    97.196667   52.403333   69.030000
# 25%     427.761667  143.800000   269.090833   88.947500  183.650833
# 50%     561.510000  179.068333   355.706667  111.855000  250.621667
# 75%     784.178333  224.175000   472.265000  148.854167  335.557500
# max    1971.063333  510.710000  1242.860000  370.800000  927.533333
#
#                  F           G           H           I           J  \
# count   148.000000  148.000000  148.000000  148.000000  148.000000
# mean    504.039775   74.359279  107.933874  107.622928   83.844459
# std     326.522184   52.354600   63.233800   35.210264   18.900730
# min      89.663333   24.156667   35.290000   53.040000   47.493333
# ...

# %%
new_df.to_csv(r'coupled_data.csv')

# %%
new_df.shape
# Out:
# (148, 19)

# %%
plt.figure(figsize=(11,8))
sns.heatmap(new_df.corr(),cmap='Blues',annot=False)

# %%
k = 18 #number of variables for heatmap
cols = new_df.corr().nlargest(k, 'Label')['Label'].index
cm = new_df[cols].corr()
plt.figure(figsize=(11,8))
sns.heatmap(cm, annot=True, cmap = 'viridis')

# %%
l = new_df.columns.values
number_of_columns=18
number_of_rows = len(l)-1/number_of_columns
plt.figure(figsize=(number_of_columns,5*number_of_rows))
for i in range(0,len(l)):
    plt.subplot(number_of_rows + 1,number_of_columns,i+1)
    sns.set_style('whitegrid')
    sns.boxplot(new_df[l[i]],color='green',orient='v')
    plt.tight_layout()

# %%
df_prediction = pd.read_csv('prediction.csv',sep =",")
df_prediction.head(333)
# Out:
#       C1            A           B           C           D           E  \
# 0      0  1420.453333  402.633333  763.776667  274.270000  659.136667
# 1      1   932.653333  313.326667  649.960000  228.303333  694.940000
# 2      2   349.826667  117.763333  217.280000   98.060000  219.710000
# 3      3   697.046667  355.410000  727.093333  215.430000  457.970000
# 4      4   373.906667  147.433333  301.936667  110.013333  254.486667
# ..   ...          ...         ...         ...         ...         ...
# 143  143   945.666667  207.980000  445.850000  110.013333  243.670000
# 144  144   471.530000  126.543333  254.280000   81.210000  201.166667
# 145  145   493.336667  158.933333  293.156667  100.210000  181.076667
# 146  146   364.793333  109.286667  206.306667   69.563333  144.760000
# 147  147   627.733333  167.410000  335.170000   84.580000  194.466667
#
#                F           G           H           I  ...           L  \
# ...

# %%
df_prediction.head(148)
# Out:
#       C1            A           B           C           D           E  \
# 0      0  1420.453333  402.633333  763.776667  274.270000  659.136667
# 1      1   932.653333  313.326667  649.960000  228.303333  694.940000
# 2      2   349.826667  117.763333  217.280000   98.060000  219.710000
# 3      3   697.046667  355.410000  727.093333  215.430000  457.970000
# 4      4   373.906667  147.433333  301.936667  110.013333  254.486667
# ..   ...          ...         ...         ...         ...         ...
# 143  143   945.666667  207.980000  445.850000  110.013333  243.670000
# 144  144   471.530000  126.543333  254.280000   81.210000  201.166667
# 145  145   493.336667  158.933333  293.156667  100.210000  181.076667
# 146  146   364.793333  109.286667  206.306667   69.563333  144.760000
# 147  147   627.733333  167.410000  335.170000   84.580000  194.466667
#
#                F           G           H           I  ...           L  \
# ...

# %%
jal_df = pd.read_csv('combined_cleaned_jal1.csv',sep =",")

# %%
plt.figure(figsize=(15,9))
sns.heatmap(jal_df.corr(),cmap='Reds',annot=False)

# %%
jal_df.describe()
# Out:
#                  A           B            C           D            E  \
# count   912.000000  912.000000   912.000000  912.000000   912.000000
# mean    463.587105  180.136294   330.001875  141.230450   332.656305
# std     408.831484  135.080119   264.485040  100.987866   283.897065
# min      26.360000   16.350000    20.690000   13.790000    20.860000
# 25%     177.435000   81.740000   144.615000   66.880000   131.167500
# 50%     330.460000  142.590000   260.080000  115.840000   253.070000
# 75%     619.192500  238.860000   439.270000  182.950000   444.512500
# max    2746.210000  938.170000  1885.930000  658.250000  2021.460000
#
#                  F            G            H           I           J  \
# count   912.000000   912.000000   912.000000  912.000000  912.000000
# mean    557.090789   240.404463   296.810186  180.580022   96.000669
# std     533.856459   202.220059   213.709534   99.710216   41.065308
# ...

# %%
k = 18 #number of variables for heatmap
cols = jal_df.corr().nlargest(k, 'Label')['Label'].index
cm = jal_df[cols].corr()
plt.figure(figsize=(11,8))
sns.heatmap(cm, annot=True, cmap = 'viridis')

# %%
jal_df.loc[:,"K"].var()
# Out:
# 12972.500652607385

# %%
jal_df.var()
# Out:
# A        167143.182079
# B         18246.638642
# C         69952.336204
# D         10198.549070
# E         80597.543745
# F        285002.719292
# G         40892.952166
# H         45671.764739
# I          9942.127214
# J          1686.359507
# K         12972.500653
# L          1240.845320
# M        618891.698728
# N         36449.926966
# O         12084.764584
# P          3789.794893
# Q         16913.536148
# R        101356.064412
# Label         0.261799
# dtype: float64
